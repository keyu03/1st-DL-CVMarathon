# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0073 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00211, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 482us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00211 to 0.00190, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 489us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00190 to 0.00190, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 488us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00190 to 0.00189, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 1s 481us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00189 to 0.00185, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 1s 478us/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00185 to 0.00179, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 1s 481us/step - loss: 9.3866e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00179 to 0.00179, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 474us/step - loss: 8.1131e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00179 to 0.00159, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 480us/step - loss: 7.0208e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00159 to 0.00140, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 479us/step - loss: 6.2047e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00140 to 0.00130, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 476us/step - loss: 5.5945e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00130 to 0.00115, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 473us/step - loss: 4.9222e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00115 to 0.00112, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 476us/step - loss: 4.6139e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00112 to 0.00101, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 479us/step - loss: 4.2962e-04 - val_loss: 9.8201e-04
#
# Epoch 00014: val_loss improved from 0.00101 to 0.00098, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 483us/step - loss: 4.1056e-04 - val_loss: 9.8008e-04
#
# Epoch 00015: val_loss improved from 0.00098 to 0.00098, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 1s 484us/step - loss: 4.0781e-04 - val_loss: 9.9480e-04
#
# Epoch 00016: val_loss did not improve from 0.00098
# Epoch 17/150
# 1712/1712 [==============================] - 1s 477us/step - loss: 3.7360e-04 - val_loss: 9.6288e-04
#
# Epoch 00017: val_loss improved from 0.00098 to 0.00096, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 473us/step - loss: 3.4440e-04 - val_loss: 8.9106e-04
#
# Epoch 00018: val_loss improved from 0.00096 to 0.00089, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 474us/step - loss: 3.4601e-04 - val_loss: 8.9891e-04
#
# Epoch 00019: val_loss did not improve from 0.00089
# Epoch 20/150
# 1712/1712 [==============================] - 1s 474us/step - loss: 3.2778e-04 - val_loss: 8.5714e-04
#
# Epoch 00020: val_loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 494us/step - loss: 3.1767e-04 - val_loss: 8.6037e-04
#
# Epoch 00021: val_loss did not improve from 0.00086
# Epoch 22/150
# 1712/1712 [==============================] - 1s 492us/step - loss: 3.1013e-04 - val_loss: 8.3593e-04
#
# Epoch 00022: val_loss improved from 0.00086 to 0.00084, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 1s 479us/step - loss: 3.0130e-04 - val_loss: 8.5951e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 1s 480us/step - loss: 3.0198e-04 - val_loss: 8.2173e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 478us/step - loss: 2.8550e-04 - val_loss: 8.9291e-04
#
# Epoch 00025: val_loss did not improve from 0.00082
# Epoch 26/150
# 1712/1712 [==============================] - 1s 483us/step - loss: 2.7530e-04 - val_loss: 8.0201e-04
#
# Epoch 00026: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 1s 477us/step - loss: 2.7494e-04 - val_loss: 8.8069e-04
#
# Epoch 00027: val_loss did not improve from 0.00080
# Epoch 28/150
# 1712/1712 [==============================] - 1s 480us/step - loss: 2.6187e-04 - val_loss: 7.8266e-04
#
# Epoch 00028: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 29/150
# 1712/1712 [==============================] - 1s 481us/step - loss: 2.5602e-04 - val_loss: 8.2966e-04
#
# Epoch 00029: val_loss did not improve from 0.00078
# Epoch 30/150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d54ffa1310e9> in <module>
#       3                        points_train,
#       4                        validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
# ----> 5                        shuffle=True, epochs=150, verbose=1)
#       6 # save the model weights
#       7 model.save_weights('weights.h5')
#
# c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     182                         # Do not slice the training phase flag.
#     183                         ins_batch = slice_arrays(
# --> 184                             fit_inputs[:-1], batch_ids) + [fit_inputs[-1]]
#     185                     else:
#     186                         ins_batch = slice_arrays(fit_inputs, batch_ids)
#
# c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\keras\utils\generic_utils.py in slice_arrays(arrays, start, stop)
#     553             if hasattr(start, 'shape'):
#     554                 start = start.tolist()
# --> 555             return [None if x is None else x[start] for x in arrays]
#     556         else:
#     557             return [None if x is None else x[start:stop] for x in arrays]
#
# c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\keras\utils\generic_utils.py in <listcomp>(.0)
#     553             if hasattr(start, 'shape'):
#     554                 start = start.tolist()
# --> 555             return [None if x is None else x[start] for x in arrays]
#     556         else:
#     557             return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, point_tests = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
'''
train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)
'''
from keras.preprocessing.image import ImageDataGenerator
#train_datagen = ImageDataGenerator(rescale = 2,shear_range = 0.2,zoom_range = 0.2,horizontal_flip = True)

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\ipykernel_launcher.py:28: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# c:\programdata\anaconda3\envs\tensorflow_gpu\lib\site-packages\ipykernel_launcher.py:28: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
# Epoch 1/20
# 66/66 [==============================] - 2s 33ms/step - loss: 0.0046 - val_loss: 0.0012
#
# Epoch 00001: val_loss did not improve from 0.00059
# Epoch 2/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0015 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00059
# Epoch 3/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00059
# Epoch 4/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00059
# Epoch 5/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00059
# Epoch 6/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00059
# Epoch 7/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00059
# Epoch 8/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0012
#
# Epoch 00008: val_loss did not improve from 0.00059
# Epoch 9/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00059
# Epoch 10/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00059
# Epoch 11/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00059
# Epoch 12/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00059
# Epoch 13/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00059
# Epoch 14/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00059
# Epoch 15/20
# 66/66 [==============================] - 2s 30ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00059
# Epoch 16/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00059
# Epoch 17/20
# 66/66 [==============================] - 2s 29ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00059
# Epoch 18/20
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00059
# Epoch 19/20
# 66/66 [==============================] - 2s 28ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00059
# Epoch 20/20
# 66/66 [==============================] - 2s 27ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00059

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(model_with_augment.history['loss'], color='b', label='Training Loss')
plt.plot(model_with_augment.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e2644d91a146> in <module>
#       2 plt.title('Optimizer : Adam', fontsize=10)
#       3 plt.ylabel('Loss', fontsize=16)
# ----> 4 plt.plot(model_with_augment.history['loss'], color='b', label='Training Loss')
#       5 plt.plot(model_with_augment.history['val_loss'], color='r', label='Validation Loss')
#       6 plt.legend(loc='upper right')
#
# TypeError: 'History' object is not subscriptable

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %%
point_tests[0]
# Out:
# array([-0.48958334], dtype=float32)
